# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
df=pd.read_csv("Boston.csv")
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296  \
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
X=df.iloc[:,1:13]
Y=df.iloc[:,-1]
X
# Out:
#        zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio       b
# 0    18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3  396.90  \
# 1     0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8  396.90
# 2     0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8  392.83
# 3     0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7  394.63
# 4     0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7  396.90
# ..    ...    ...   ...    ...    ...   ...     ...  ...  ...      ...     ...
# 501   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0  391.99
# 502   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0  396.90
# 503   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0  396.90
# 504   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0  393.45
# 505   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0  396.90
#
#      lstat
# 0     4.98
# 1     9.14
# 2     4.03
# 3     2.94
# 4     5.33
# ..     ...
# 501   9.67
# 502   9.08
# 503   5.64
# 504   6.48
# 505   7.88
#
# [506 rows x 12 columns]

# %%
Y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
mms=MinMaxScaler()
mms.fit(X_train)
X_train=mms.transform(X_train)
X_test=mms.transform(X_test)

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
# Out:
# 2024-04-21 20:03:38.528987: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model=Sequential()
model.add(Dense(128,activation='relu',name='Input'))
model.add(Dense(64,activation='relu',name='Hidden'))
model.add(Dense(1,activation='linear',name='Dense_Output'))

# %%
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Input (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden (Dense)                  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_Output (Dense)            │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
history=model.fit(X_train,Y_train,validation_split=0.05,epochs=10,verbose=1)
# Out:
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 568.4291 - mae: 22.0574 - val_loss: 609.1302 - val_mae: 22.7209
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 531.7857 - mae: 21.1586 - val_loss: 554.7904 - val_mae: 21.4585
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 518.8764 - mae: 20.5643 - val_loss: 467.9145 - val_mae: 19.2476
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 419.7804 - mae: 17.9003 - val_loss: 342.8118 - val_mae: 15.7089
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 302.0667 - mae: 14.3645 - val_loss: 211.4240 - val_mae: 12.3026
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 172.6000 - mae: 10.3590 - val_loss: 137.4313 - val_mae: 9.7037
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 139.7844 - mae: 9.2150 - val_loss: 119.8592 - val_mae: 8.8239
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 148.9812 - mae: 9.5263 - val_loss: 105.5856 - val_mae: 8.2347
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 103.5616 - mae: 7.8359 - val_loss: 96.2115 - val_mae: 7.7604
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 98.6345 - mae: 7.3463 - val_loss: 86.0220 - val_mae: 7.2316

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# array([[23.211647],
#        [17.504047],
#        [21.156666],
#        [22.25825 ],
#        [19.562914],
#        [19.515102],
#        [20.051462],
#        [23.800344],
#        [20.093868],
#        [19.679977],
#        [20.376268],
#        [20.125946],
#        [22.356394],
#        [22.514626],
#        [18.170765],
#        [19.46943 ],
#        [23.612413],
#        [18.607668],
#        [19.25132 ],
#        [20.346565],
#        [18.794548],
#        [18.45501 ],
#        [24.42812 ],
#        [18.749332],
#        [18.936924],
#        [17.84805 ],
#        [20.643139],
#        [19.306637],
#        [18.931791],
#        [24.694092],
#        [17.270958],
#        [19.113653],
#        [20.448303],
#        [19.972961],
#        [20.22625 ],
#        [24.497032],
#        [24.59808 ],
#        [19.53783 ],
#        [18.88648 ],
#        [17.339664],
#        [19.661469],
#        [19.763237],
#        [18.982988],
#        [19.019424],
#        [25.085554],
#        [20.016502],
#        [22.876375],
#        [22.975344],
#        [19.907272],
#        [17.237602],
#        [20.140877],
#        [21.579987],
#        [18.166716],
#        [18.700775],
#        [19.01268 ],
#        [17.361727],
#        [18.200165],
#        [19.716248],
#        [23.909899],
#        [27.874641],
#        [20.083702],
#        [24.223097],
#        [24.963034],
#        [19.867275],
#        [20.215748],
#        [20.631231],
#        [24.316921],
#        [18.486286],
#        [20.38337 ],
#        [19.4651  ],
#        [22.519896],
#        [19.568352],
#        [20.344498],
#        [19.746552],
#        [19.709213],
#        [22.99899 ],
#        [19.73543 ],
#        [25.118542],
#        [22.480453],
#        [20.043226],
#        [21.46251 ],
#        [20.779934],
#        [20.53569 ],
#        [21.082363],
#        [19.726345],
#        [20.17283 ],
#        [20.839226],
#        [24.333721],
#        [19.77901 ],
#        [22.180855],
#        [19.151554],
#        [21.257383],
#        [23.55267 ],
#        [20.226545],
#        [28.82743 ],
#        [19.464252],
#        [17.5919  ],
#        [20.476433],
#        [22.099556],
#        [19.457222],
#        [20.248985],
#        [18.531748],
#        [21.35323 ],
#        [21.214874],
#        [19.683777],
#        [22.561356],
#        [24.730648],
#        [19.421516],
#        [18.342838],
#        [17.284023],
#        [21.33073 ],
#        [21.093842],
#        [20.346714],
#        [18.557535],
#        [23.393482],
#        [22.464676],
#        [21.555357],
#        [20.756565],
#        [19.783854],
#        [23.3117  ],
#        [21.13242 ],
#        [21.052307],
#        [22.208248],
#        [18.927786],
#        [20.66417 ],
#        [25.930252],
#        [20.095303],
#        [18.243141],
#        [21.116234],
#        [19.43296 ],
#        [24.608698],
#        [20.693787],
#        [20.566189],
#        [20.75113 ],
#        [18.709545],
#        [18.951069],
#        [19.87429 ],
#        [21.028467],
#        [23.972927],
#        [23.097206],
#        [19.588665],
#        [22.574444],
#        [20.56599 ],
#        [18.446133],
#        [18.34324 ],
#        [20.662037],
#        [22.658482],
#        [20.242096],
#        [24.334862],
#        [20.503654],
#        [19.405708],
#        [23.082146]], dtype=float32)
