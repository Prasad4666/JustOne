# %%
import pandas as pd

# %%
df=pd.read_csv("Boston.csv")
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296  \
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
x=df.iloc[:,0:13]
y=df.iloc[:,-1]

# %%
x
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296  \
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()

mms.fit(x_train)
x_train=mms.transform(x_train)
x_test=mms.transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model=Sequential()

model.add(Dense(128, activation='relu', name='Input'))
model.add(Dense(64,activation='relu', name='hidden'))
model.add(Dense(1,activation='linear', name='dense_output'))
# Out:
# 2024-04-21 19:51:54.120140: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Input (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden (Dense)                  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_output (Dense)            │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(x_train, y_train, epochs=10, validation_split=0.05, verbose = 1)
# Out:
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 560.7567 - mae: 22.1478 - val_loss: 543.9963 - val_mae: 22.0477
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 502.9219 - mae: 20.7210 - val_loss: 495.7847 - val_mae: 20.8793
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 452.6749 - mae: 19.4078 - val_loss: 420.1837 - val_mae: 18.8864
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 383.6036 - mae: 17.2601 - val_loss: 312.6248 - val_mae: 15.9522
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 258.3162 - mae: 13.3219 - val_loss: 193.3671 - val_mae: 12.4667
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 166.3977 - mae: 9.7377 - val_loss: 114.3561 - val_mae: 8.9719
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 114.9852 - mae: 8.0767 - val_loss: 90.9249 - val_mae: 7.3380
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 104.8239 - mae: 7.6491 - val_loss: 75.9360 - val_mae: 6.8001
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 97.9232 - mae: 7.4768 - val_loss: 62.9968 - val_mae: 6.3936
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 77.8484 - mae: 6.2793 - val_loss: 51.3981 - val_mae: 5.7337

# %%
y_pred=model.predict(x_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
y_pred
# Out:
# array([[22.182117],
#        [20.487543],
#        [24.399363],
#        [19.771423],
#        [24.176569],
#        [19.422827],
#        [18.941175],
#        [21.22769 ],
#        [20.035372],
#        [23.849339],
#        [22.773935],
#        [22.149641],
#        [20.333855],
#        [19.14838 ],
#        [23.569262],
#        [20.656933],
#        [20.179945],
#        [22.37591 ],
#        [19.525389],
#        [17.794949],
#        [22.838493],
#        [21.16066 ],
#        [19.845972],
#        [18.691116],
#        [23.367712],
#        [21.719883],
#        [23.506079],
#        [19.272371],
#        [21.55551 ],
#        [20.736773],
#        [24.80903 ],
#        [19.540142],
#        [21.471014],
#        [24.042387],
#        [23.796978],
#        [20.46744 ],
#        [20.10514 ],
#        [18.61854 ],
#        [23.456923],
#        [22.069805],
#        [23.179049],
#        [19.887087],
#        [20.472427],
#        [20.680326],
#        [17.250114],
#        [21.318205],
#        [20.035128],
#        [20.23134 ],
#        [20.632004],
#        [19.726915],
#        [23.292742],
#        [19.88587 ],
#        [26.584826],
#        [22.986488],
#        [20.914915],
#        [23.202574],
#        [25.78242 ],
#        [19.614735],
#        [19.20429 ],
#        [22.33986 ],
#        [20.543781],
#        [24.681759],
#        [21.052027],
#        [21.957737],
#        [20.183777],
#        [23.922525],
#        [23.90494 ],
#        [23.234764],
#        [18.109987],
#        [19.553797],
#        [20.862513],
#        [21.131565],
#        [23.93321 ],
#        [19.273798],
#        [24.356247],
#        [22.38766 ],
#        [20.434557],
#        [23.451265],
#        [20.913637],
#        [23.17827 ],
#        [18.906063],
#        [18.65818 ],
#        [21.417875],
#        [18.122229],
#        [21.438385],
#        [21.953468],
#        [21.071955],
#        [19.137863],
#        [17.311708],
#        [20.867773],
#        [20.566599],
#        [18.241716],
#        [16.596733],
#        [21.873108],
#        [22.680183],
#        [24.755777],
#        [24.531183],
#        [18.65145 ],
#        [24.098509],
#        [18.718729],
#        [18.43133 ],
#        [21.399488],
#        [18.921797],
#        [23.049816],
#        [23.307053],
#        [20.055746],
#        [21.129307],
#        [18.234068],
#        [23.666441],
#        [24.259726],
#        [23.258047],
#        [24.002356],
#        [22.463232],
#        [23.395071],
#        [25.23398 ],
#        [23.71979 ],
#        [19.745306],
#        [19.841206],
#        [19.07964 ],
#        [23.98819 ],
#        [19.933386],
#        [22.01871 ],
#        [19.336454],
#        [20.909733],
#        [23.669977],
#        [23.422754],
#        [22.488445],
#        [18.398977],
#        [19.446573],
#        [20.703058],
#        [20.243639],
#        [21.03828 ],
#        [24.007214],
#        [19.005894],
#        [19.361994],
#        [21.403223],
#        [19.392712],
#        [23.73519 ],
#        [20.33845 ],
#        [23.297228],
#        [23.335773],
#        [18.94441 ],
#        [23.298477],
#        [21.977198],
#        [17.23261 ],
#        [22.435907],
#        [21.520683],
#        [20.343552],
#        [19.982296],
#        [20.257635],
#        [22.041822],
#        [19.164568]], dtype=float32)
